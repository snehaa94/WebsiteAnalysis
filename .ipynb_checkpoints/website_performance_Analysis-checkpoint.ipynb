# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data-export.csv")

# %%
df.head()
# Out:
#     channel group    DateHour Users Sessions Engaged Sessions  \
# 0  Organic Social  2024041719   208      267              132
# 1          Direct  2024041723   188      233              115
# 2  Organic Social  2024041718   187      256              125
# 3  Organic Social  2024041720   175      221              112
# 4  Organic Social  2024041721   160      206              103
#
#   Average engagement time per session Engaged sessions per user  \
# 0                   32.09737827715360        0.6346153846153850
# 1                   39.93991416309010        0.6117021276595740
# 2                         32.16015625        0.6684491978609630
# 3                  46.918552036199100                      0.64
# 4                   59.31553398058250                   0.64375
#
#   Events per session      Engagement rate Event count
# 0  4.295880149812730   0.4943820224719100        1147
# 1  4.587982832618030  0.49356223175965700        1069
# 2           4.078125           0.48828125        1044
# 3  4.529411764705880   0.5067873303167420        1001
# 4  4.694174757281550                  0.5         967

# %%
df.columns = df.iloc[0]
df = df.drop(index=0).reset_index(drop=True)
df.columns = [
    "channel group",
    "DateHour",
    "Users",
    "Sessions",
    "Engaged Sessions",
    "Average engagement time per session",
    "Engaged sessions per user",
    "Events per session",
    "Engagement rate",
    "Event count"
]

# %%
df.head()
# Out:
#     channel group    DateHour Users Sessions Engaged Sessions  \
# 0  Organic Social  2024041720   175      221              112
# 1  Organic Social  2024041721   160      206              103
# 2  Organic Social  2024050119   160      219              110
# 3          Direct  2024041622   158      192               94
# 4  Organic Social  2024041321   152      178               96
#
#   Average engagement time per session Engaged sessions per user  \
# 0                  46.918552036199100                      0.64
# 1                   59.31553398058250                   0.64375
# 2                   40.31506849315070                    0.6875
# 3                  39.020833333333300        0.5949367088607590
# 4                   30.48876404494380         0.631578947368421
#
#   Events per session     Engagement rate Event count
# 0  4.529411764705880  0.5067873303167420        1001
# 1  4.694174757281550                 0.5         967
# 2   4.63013698630137   0.502283105022831        1014
# 3  4.057291666666670  0.4895833333333330         779
# 4  5.056179775280900  0.5393258426966290         900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3178 non-null   object
#  1   DateHour                             3178 non-null   object
#  2   Users                                3178 non-null   object
#  3   Sessions                             3178 non-null   object
#  4   Engaged Sessions                     3178 non-null   object
#  5   Average engagement time per session  3178 non-null   object
#  6   Engaged sessions per user            3178 non-null   object
#  7   Events per session                   3178 non-null   object
#  8   Engagement rate                      3178 non-null   object
#  9   Event count                          3178 non-null   object
# dtypes: object(10)
# memory usage: 248.4+ KB

# %%
df["DateHour"] = pd.to_datetime(df["DateHour"], format="%Y%m%d%H", errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3178 non-null   object
#  1   DateHour                             3178 non-null   datetime64[ns]
#  2   Users                                3178 non-null   int64
#  3   Sessions                             3178 non-null   int64
#  4   Engaged Sessions                     3178 non-null   int64
#  5   Average engagement time per session  3178 non-null   float64
#  6   Engaged sessions per user            3178 non-null   float64
#  7   Events per session                   3178 non-null   float64
#  8   Engagement rate                      3178 non-null   float64
#  9   Event count                          3178 non-null   int64
#  10  Hour                                 3178 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(4), object(1)
# memory usage: 260.8+ KB

# %%
numeric_cols = df.columns.drop(["channel group", "DateHour"])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")
df["Hour"] = df["DateHour"].dt.hour

# %%
df.head()
# Out:
#     channel group            DateHour  Users  Sessions  Engaged Sessions  \
# 0  Organic Social 2024-04-17 20:00:00    175       221               112
# 1  Organic Social 2024-04-17 21:00:00    160       206               103
# 2  Organic Social 2024-05-01 19:00:00    160       219               110
# 3          Direct 2024-04-16 22:00:00    158       192                94
# 4  Organic Social 2024-04-13 21:00:00    152       178                96
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            46.918552                   0.640000
# 1                            59.315534                   0.643750
# 2                            40.315068                   0.687500
# 3                            39.020833                   0.594937
# 4                            30.488764                   0.631579
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.529412         0.506787         1001    20
# 1            4.694175         0.500000          967    21
# 2            4.630137         0.502283         1014    19
# 3            4.057292         0.489583          779    22
# 4            5.056180         0.539326          900    21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3178 non-null   object
#  1   DateHour                             3178 non-null   datetime64[ns]
#  2   Users                                3178 non-null   int64
#  3   Sessions                             3178 non-null   int64
#  4   Engaged Sessions                     3178 non-null   int64
#  5   Average engagement time per session  3178 non-null   float64
#  6   Engaged sessions per user            3178 non-null   float64
#  7   Events per session                   3178 non-null   float64
#  8   Engagement rate                      3178 non-null   float64
#  9   Event count                          3178 non-null   int64
#  10  Hour                                 3178 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(4), object(1)
# memory usage: 260.8+ KB

# %%
df.describe()
# Out:
#                             DateHour        Users     Sessions  \
# count                           3178  3178.000000  3178.000000
# mean   2024-04-20 01:21:32.511013376    41.730648    50.924795
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:00:00    20.000000    24.000000
# 50%              2024-04-20 03:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   175.000000   221.000000
# std                              NaN    29.020227    36.152124
#
#        Engaged Sessions  Average engagement time per session  \
# count       3178.000000                          3178.000000
# mean          28.198867                            66.680722
# min            0.000000                             0.000000
# 25%           13.000000                            32.076875
# 50%           27.000000                            49.105769
# 75%           41.000000                            71.527778
# max          125.000000                          4525.000000
# std           20.348601                           127.276425
#
#        Engaged sessions per user  Events per session  Engagement rate  \
# count                3178.000000         3178.000000      3178.000000
# mean                    0.606419            4.676305         0.503414
# min                     0.000000            1.000000         0.000000
# 25%                     0.561404            3.750000         0.442857
# 50%                     0.666667            4.410256         0.545923
# 75%                     0.750000            5.219381         0.633333
# max                     2.000000           56.000000         1.000000
# std                     0.264186            2.796958         0.228349
#
#        Event count         Hour
# count  3178.000000  3178.000000
# mean    241.110447    11.795784
# min       1.000000     0.000000
# 25%     103.000000     6.000000
# 50%     225.500000    12.000000
# 75%     339.000000    18.000000
# max    1117.000000    23.000000
# std     181.552385     6.883226

# %% [markdown]
# # sessions and user over time

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,5))
df.groupby("DateHour")[["Sessions","Users"]].sum().plot(ax=plt.gca())
plt.title("Sessions and users over time")
plt.show()

# %% [markdown]
# # total users by channels

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="channel group", y="Users", estimator=np.sum, palette="viridis")
plt.title("👥 Total users by Channels")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_12860\3136057627.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y="Users", estimator=np.sum, palette="viridis")
# C:\Users\SNEHA\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128101 (\N{BUSTS IN SILHOUETTE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # average engagement time by channel

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="channel group", y="Average engagement time per session", estimator=np.mean, palette="magma")
plt.title("Avg Engagement Time by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_12860\3010706690.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y="Average engagement time per session", estimator=np.mean, palette="magma")

# %% [markdown]
# # Engagement Rate Distributions by channel

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="channel group", y="Engagement rate", palette="coolwarm")
plt.title("Engagement Rate Distribution by Channels")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SNEHA\AppData\Local\Temp\ipykernel_12860\1478651119.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="channel group", y="Engagement rate", palette="coolwarm")
